# %%
# %matplotlib inline
import pandas as pd
import mplfinance as mpf

# %%
file = 'C:\\Users\\suler\\PycharmProjects\\algorithmic-trading-python\\yahoo-finance\\CCIV.csv'
data = pd.read_csv(file)

# %%
data
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2020-09-18  10.250000  10.250000   9.820000   9.890000   9.890000
# 1   2020-09-21   9.900000   9.960000   9.860000   9.860000   9.860000
# 2   2020-09-22   9.960000   9.960000   9.850000   9.880000   9.880000
# 3   2020-09-23   9.900000   9.905000   9.790000   9.850000   9.850000
# 4   2020-09-24   9.850000   9.850000   9.750000   9.770000   9.770000
# ..         ...        ...        ...        ...        ...        ...
# 82  2021-01-15  17.809999  21.000000  16.200001  18.360001  18.360001
# 83  2021-01-19  18.049999  18.690001  17.500000  17.900000  17.900000
# 84  2021-01-20  18.350000  18.730000  17.799999  18.059999  18.059999
# 85  2021-01-21  18.090000  18.250000  17.110001  17.809999  17.809999
# 86  2021-01-22  18.490000  22.670000  18.000000  22.350000  22.350000
#
#        Volume
# 0      564300
# 1      762800
# 2     1280800
# 3      192600
# 4      605500
# ..        ...
# 82  184854200
# ...
